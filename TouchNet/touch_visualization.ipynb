# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
touch_prediction_path = '/viscam/u/rhgao/datasets/ObjectFiles/GoogleScannedObjects/Chefmate_8_Frypan/touch_prediction.npy'
touch_prediction = np.load(touch_prediction_path)
print(touch_prediction.shape)
# Out:
# (4658, 160, 120, 3)

# %%
img = Image.fromarray(touch_prediction[29].astype(np.uint8), 'RGB')
plt.axis('off')
plt.imshow(img)
plt.savefig('pred.png', bbox_inches = 'tight', format='png', dpi=300)

# %%
touch_prediction_path = '/viscam/u/rhgao/datasets/ObjectFiles/GoogleScannedObjects/Chefmate_8_Frypan/touch.npy'
touch_prediction = np.load(touch_prediction_path)
print(touch_prediction.shape)
# Out:
# (4658, 160, 120, 3)

# %%
img = Image.fromarray(touch_prediction[29].astype(np.uint8), 'RGB')
plt.axis('off')
plt.imshow(img)
plt.savefig('gt.png', bbox_inches = 'tight', format='png', dpi=300)

# %%
touch_prediction_path = '/viscam/u/rhgao/datasets/ObjectFiles/modelhaven/13/touch_prediction.npy'
touch_prediction = np.load(touch_prediction_path)
print(touch_prediction.shape)
img = Image.fromarray(touch_prediction[50].astype(np.uint8), 'RGB')
plt.imshow(img)
# Out:
# (112, 160, 120, 3)

# %%
def _to_uint8(depth):
    min_, max_ = depth.min(), depth.max()
    return ((depth - min_) / (max_ - min_) * 255).astype(np.uint8)

print(depth_example.shape)
print(depth_example.min())
depth = _to_uint8(depth_example)

img = Image.fromarray(depth[0])
plt.imshow(img, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6d7efdfea80e> in <module>
#       3     return ((depth - min_) / (max_ - min_) * 255).astype(np.uint8)
#       4
# ----> 5 print(depth_example.shape)
#       6 print(depth_example.min())
#       7 depth = _to_uint8(depth_example)
#
# NameError: name 'depth_example' is not defined

# %%
verts_forces_matrix = np.load('/viscam/u/small02/touch_sim_data_keyboard/keyboard_verts_forces.npy')
print(verts_forces_matrix.shape)
print(verts_forces_matrix)
# Out:
# (4280, 4)
# [[-1.28448000e-01  3.56100000e-03  1.66730000e-02  1.43321229e+00]
#  [-1.06816000e-01  4.13760000e-02  2.00760000e-02  1.11980532e+00]
#  [ 1.12000000e-02  3.17590000e-02  1.83990000e-02  1.55144056e+00]
#  ...
#  [ 9.82630000e-02 -1.72330000e-02  1.35660000e-02  1.62214469e+00]
#  [ 9.81500000e-03  6.00210000e-02  1.51860000e-02  4.02233953e+00]
#  [-6.94810000e-02  4.10300000e-02  1.86300000e-03  2.92497029e+01]]
